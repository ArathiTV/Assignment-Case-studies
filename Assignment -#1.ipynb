# %%
import pandas as pd
import numpy as np
import matplotlib .pyplot as plt
import seaborn as sns

# %% [markdown]
# ###  1.    Read the dataset to python environment.

# %%
# Read the Iris.excel file into dataframe.
data = pd.read_excel('C:\\Users\\Arathi\\Downloads\\iris.xls')

# %%
# display the dataset
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### 2.        Display the columns in the dataset

# %%
#display the columns in the dataset
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ### 3. Calculate the mean of each columns of the dataset.

# %%
# calculating the mean of each columns
data.mean()
# Out:
# C:\Users\Arathi\AppData\Local\Temp\ipykernel_32504\718583613.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ### 4.   Check for the null values present in the dataset

# %% [markdown]
# #### methode 1

# %%
# check the null values in the dataset
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# #### methode 2

# %%
# check the null values
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ### 5.    Perform meaningful visualization using the dataset.Bring at least 3  visualizations

# %% [markdown]
# ### 1.  bar plot for 3 classification

# %%
# set the figuresize
plt.figure(figsize=(8,7))
# creating bar plot
plt.bar(data['Classification'],data['SL'])
# set the title,y-axis ,x-axis with fontsize
plt.title('Bar plot for 3 Classification',fontsize=19)
plt.ylabel('Sepal Length',fontsize=15)
plt.xlabel('Classification', fontsize=15)
# show the plot
plt.show()

# %% [markdown]
# ### 2.  Scatter plot of PL and PW

# %%
# creating the scatterplot
plt.scatter(data['PL'],data['PW'])
# set title,y-axis,x-axis with fontsize
plt.title('scatter plot of PL and PW',fontsize=20)   
plt.ylabel('y-axis',fontsize=15)
plt.xlabel('x-axis',fontsize=15)
# show the plot
plt.show()

# %% [markdown]
# ### 3.  Bar plot of petal_width and petal_length

# %%
# set the figure size
plt.figure(figsize=(7,6))
# creating the bar plot
plt.bar(data['PW'], data['PL'],color=['yellow'])
# set the title,x-axis,y-axis with fontsize
plt.xlabel('Petal width',fontsize=15)
plt.title('petal width and petal length',fontsize=19)
plt.ylabel('Petal length',fontsize= 15)
# show the plot
plt.show()

# %% [markdown]
# ### 4. Seaborn Plots

# %%
# creating the pairsplot in seaborn
sns.pairplot(data)
# show the plot
plt.show()

# %% [markdown]
# ### 5. box plot

# %%
# set figure size
plt.figure(figsize=(10,7))
# creating the boxplot , #  5 summury statistic
plt.boxplot([data['SL'],data['SW'],data['PL'],data['PW']])
# set the title with fontsize
plt.title('Box plots Iris Features',fontsize=22)
# show the plot
plt.show()

# %% [markdown]
# ### 6. Line plot of Iris dataset

# %%
# set the figure size
plt.figure(figsize=(29,25))
# creating line plot
data.plot()
# set title and legend
plt.title('Iris Dataset',fontsize=19)
plt.legend()
# show the plot
plt.show()

# %% [markdown]
# ### 7.  Histogram

# %%
# creating the histogram
data['SL'].hist()
# show the plot
plt.show()
